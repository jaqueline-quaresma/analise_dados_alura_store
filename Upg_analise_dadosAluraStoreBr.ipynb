# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
sum_loja1 = loja['Preço'].sum()
sum_loja2 = loja2['Preço'].sum()
sum_loja3 = loja3['Preço'].sum()
sum_loja4 = loja4['Preço'].sum()

faturamento_loja1 = sum_loja1
faturamento_loja2 = sum_loja2
faturamento_loja3 = sum_loja3
faturamento_loja4 = sum_loja4


print(f"Faturamento loja1: R${faturamento_loja1:,.2f}")

print(f"Faturamento loja2: R${faturamento_loja2:,.2f}")

print(f"Faturamento loja3: R${faturamento_loja3:,.2f}")

print(f"Faturamento loja4: R${faturamento_loja4:,.2f}")

import matplotlib.pyplot as plt

# Dados para o gráfico de barras (substitua pelos seus dados)
lojas = ['loja1', 'loja2', 'loja3', 'loja4']
faturamentos = [faturamento_loja1, faturamento_loja2, faturamento_loja3, faturamento_loja4]

# Criando o gráfico de barras
plt.figure(figsize=(10, 6))  # Ajuste o tamanho da figura conforme necessário
plt.bar(lojas, faturamentos, color=['skyblue', 'lightcoral', 'lightgreen', 'gold']) # Cores personalizadas
plt.xlabel("Lojas")
plt.ylabel("Faturamento (R$)")
plt.title("Faturamento por Loja")
plt.grid(axis='y', linestyle='--', alpha=0.7)


# Adicionando os valores acima das barras
for i, valor in enumerate(faturamentos):
    plt.text(i, valor, f'{valor:,.2f}', ha='center', va='bottom')

plt.show()
# Out:
# Faturamento loja1: R$1,384,497.58
# Faturamento loja2: R$1,488,459.06
# Faturamento loja3: R$1,464,025.03
# Faturamento loja4: R$1,384,497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
#lojas = pd.concat([loja, loja2, loja3, loja4])

#vendas_por_categoria = lojas.groupby('Categoria do Produto')['Avaliação da compra'].sum()

#print (vendas_por_categoria)

#categoria_mais_popular = vendas_por_categoria.idxmax()
#quantidade_vendas_categoria_mais_popular = vendas_por_categoria.max()

#print(f"A categoria mais popular é: {categoria_mais_popular} com {quantidade_vendas_categoria_mais_popular} vendas.")

lojas = [loja1, loja2, loja3, loja4]
loja_id = ['loja1', 'loja2', 'loja3', 'loja4']

for i, loja in enumerate(lojas):
  vendas_por_categoria = loja.groupby('Categoria do Produto')['Avaliação da compra'].sum()
  categoria_mais_vendida = vendas_por_categoria.idxmax()
  quantidade_categoria_mais_vendida = vendas_por_categoria.max()
  categoria_menos_vendida = vendas_por_categoria.idxmin()
  quantidade_categoria_menos_vendida = vendas_por_categoria.min()
  print(f"--- {loja_id[i]} ---")
  print(vendas_por_categoria)
  print(f"Categoria mais vendida: {categoria_mais_vendida} - Quantidade: {quantidade_categoria_mais_vendida}")
  print(f"Categoria menos vendida: {categoria_menos_vendida} - Quantidade: {quantidade_categoria_menos_vendida}")
  print("\n")
# Out:
# --- loja1 ---
# Categoria do Produto
# brinquedos               1321
# eletrodomesticos         1258
# eletronicos              1794
# esporte e lazer          1107
# instrumentos musicais     737
# livros                    688
# moveis                   1835
# utilidades domesticas     641
# Name: Avaliação da compra, dtype: int64
# Categoria mais vendida: moveis - Quantidade: 1835
# Categoria menos vendida: utilidades domesticas - Quantidade: 641
#
#
# --- loja2 ---
# Categoria do Produto
# brinquedos               1260
# eletrodomesticos         1242
# eletronicos              1676
# esporte e lazer          1118
# instrumentos musicais     904
# livros                    778
# moveis                   1809
# utilidades domesticas     737
# Name: Avaliação da compra, dtype: int64
# Categoria mais vendida: moveis - Quantidade: 1809
# Categoria menos vendida: utilidades domesticas - Quantidade: 737
#
#
# --- loja3 ---
# Categoria do Produto
# brinquedos               1322
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
sum_loja1 = loja['Avaliação da compra'].sum()
sum_loja2 = loja2['Avaliação da compra'].sum()
sum_loja3 = loja3['Avaliação da compra'].sum()
sum_loja4 = loja4['Avaliação da compra'].sum()

#avaliacao_loja1 = sum_loja1

#formatted_avaliacao_loja1 = "{:.0f}".format(avaliacao_loja1)

#print(f"Somatoria de Avaliações da loja1: {formatted_avaliacao_loja1}")

#avaliacao_loja2 = sum_loja2

#formatted_avaliacao_loja2 = "{:.0f}".format(avaliacao_loja2)

#print(f"Somatoria de Avaliações da loja2: {formatted_avaliacao_loja2}")

#avaliacao_loja3 = sum_loja3

#formatted_avaliacao_loja3 = "{:.0f}".format(avaliacao_loja3)

#print(f"Somatoria de Avaliações da loja3: {formatted_avaliacao_loja3}")

#avaliacao_loja4 = sum_loja4

#formatted_avaliacao_loja4 = "{:.0f}".format(avaliacao_loja4)

#print(f"Somatoria de Avaliações da loja4: {formatted_avaliacao_loja4}")

quantidade_avaliacao_loja1 = len(loja)
quantidade_avaliacao_loja2 = len(loja2)
quantidade_avaliacao_loja3 = len(loja3)
quantidade_avaliacao_loja4 = len(loja4)

#print (f"Quantidade de Avaliações da loja: {int(quantidade_avaliacao_loja1)}")
#print (f"Quantidade de Avaliações da loja2: {int(quantidade_avaliacao_loja2)}")
#print (f"Quantidade de Avaliações da loja3: {int(quantidade_avaliacao_loja3)}")
#print (f"Quantidade de Avaliações da loja4: {int(quantidade_avaliacao_loja4)}")

media_loja1 = avaliacao_loja1 / quantidade_avaliacao_loja1
formatted_media = "{:.2f}".format(media_loja1)

print(f"Média de Avaliações loja1: {formatted_media}")

media_loja2 = avaliacao_loja2 / quantidade_avaliacao_loja2
formatted_media = "{:.2f}".format(media_loja2)

print(f"Média de Avaliações loja2: {formatted_media}")

media_loja3 = avaliacao_loja3 / quantidade_avaliacao_loja3
formatted_media = "{:.2f}".format(media_loja3)

print(f"Média de Avaliações loja3: {formatted_media}")

media_loja4 = avaliacao_loja4 / quantidade_avaliacao_loja4
formatted_media = "{:.2f}".format(media_loja4)

print(f"Média de Avaliações loja4: {formatted_media}")

media = {
    'loja1': media_loja1,
    'loja2': media_loja2,
    'loja3': media_loja3,
    'loja4': media_loja4
}
import matplotlib.pyplot as plt

# Encontrar a loja com a maior média de avaliação
melhor_loja = max(media, key=media.get)
maior_media = media[melhor_loja]

print(f"A loja com mais clientes satisfeitos é: {melhor_loja} com média {maior_media:.2f}")

# Criando o gráfico de linhas
plt.figure(figsize=(10, 6))
plt.plot(lojas, medias, marker='o', linestyle='-', color='b')  # 'o' para marcadores circulares
plt.xlabel("Lojas")
plt.ylabel("Média de Avaliação")
plt.title("Média de Avaliação por Loja")
plt.grid(True)

# Adicionando os valores acima dos pontos
for i, media in enumerate(medias):
    plt.text(i, media, f'{media:.2f}', ha='center', va='bottom')

plt.show()
# Out:
# Média de Avaliações loja1: 3.98
# Média de Avaliações loja2: 4.04
# Média de Avaliações loja3: 4.05
# Média de Avaliações loja4: 4.00
# A loja com mais clientes satisfeitos é: loja3 com média 4.05

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
#Analisar coluna Produto e Avaliação da compra
#lojas = pd.concat([loja])

#produtos_vendidos = lojas.groupby('Produto')['Avaliação da compra'].sum()

#print (produtos_vendidos)

#produto_mais_popular = produtos_vendidos.idxmax()
#quantidade_vendas_produto_mais_popular = produtos_vendidos.max()

#print(f"O produto mais vendido na loja1 é: {produto_mais_popular} com {quantidade_vendas_produto_mais_popular} vendas.")

lojas = [loja1, loja2, loja3, loja4]
loja_id = ['loja1', 'loja2', 'loja3', 'loja4']

for i, loja in enumerate(lojas):
  produtos_vendidos = loja.groupby('Produto')['Avaliação da compra'].sum()
  produto_mais_vendido = produtos_vendidos.idxmax()
  quantidade_mais_vendido = produtos_vendidos.max()
  produto_menos_vendido = produtos_vendidos.idxmin()
  quantidade_menos_vendido = produtos_vendidos.min()

  print(f"--- {loja_id[i]} ---")
  print(f"Produto mais vendido: {produto_mais_vendido} (Quantidade: {quantidade_mais_vendido})")
  print(f"Produto menos vendido: {produto_menos_vendido} (Quantidade: {quantidade_menos_vendido})")
  print("\n")
# Out:
# --- loja1 ---
# Produto mais vendido: TV Led UHD 4K (Quantidade: 243)
# Produto menos vendido: Celular ABXY (Quantidade: 126)
#
#
# --- loja2 ---
# Produto mais vendido: Iniciando em programação (Quantidade: 260)
# Produto menos vendido: Jogo de tabuleiro (Quantidade: 127)
#
#
# --- loja3 ---
# Produto mais vendido: Kit banquetas (Quantidade: 240)
# Produto menos vendido: Micro-ondas (Quantidade: 126)
#
#
# --- loja4 ---
# Produto mais vendido: Cama box (Quantidade: 247)
# Produto menos vendido: Guitarra (Quantidade: 125)

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
#sum_loja1 = loja['Frete'].sum()
#sum_loja2 = loja2['Frete'].sum()
#sum_loja3 = loja3['Frete'].sum()
#sum_loja4 = loja4['Frete'].sum()

#frete_loja1 = sum_loja1

#formatted_frete_loja1 = "{:.2f}".format(frete_loja1)

#print(f"Somatoria de Frete da loja1: R${formatted_frete_loja1}")

#frete_loja2 = sum_loja2

#formatted_frete_loja2 = "{:.2f}".format(frete_loja2)

#print(f"Somatoria de Frete da loja2: R${formatted_frete_loja2}")

#frete_loja3 = sum_loja3

#formatted_frete_loja3 = "{:.2f}".format(frete_loja3)

#print(f"Somatoria de Frete da loja3: R${formatted_frete_loja3}")

#frete_loja4 = sum_loja4

#formatted_frete_loja4 = "{:.2f}".format(frete_loja4)

#print(f"Somatoria de Frete da loja4: R${formatted_frete_loja4}")


#quantidade_frete_loja1 = len(loja)
#quantidade_frete_loja2 = len(loja2)
#quantidade_frete_loja3 = len(loja3)
#quantidade_frete_loja4 = len(loja4)

#quant_frete_loja1 = quantidade_frete_loja1
#formatted_quant_frete_loja1 = "{:.0f}".format(quant_frete_loja1)

#print(f"Quantidade de Fretes da loja1: {formatted_quant_frete_loja1}")


#quant_frete_loja2 = quantidade_frete_loja2

#formatted_quant_frete_loja2 = "{:.0f}".format(quant_frete_loja2)

#print(f"Quantidade de Fretes da loja2: {formatted_quant_frete_loja2}")

#quant_frete_loja3 = quantidade_frete_loja3

#formatted_quant_frete_loja3 = "{:.0f}".format(quant_frete_loja3)

#print(f"Quantidade de Fretes da loja3: {formatted_quant_frete_loja3}")

#quant_frete_loja4 = quantidade_frete_loja4

#formatted_quant_frete_loja4 = "{:.0f}".format(quant_frete_loja4)

#print(f"Quantidade de Fretes da loja4: {formatted_quant_frete_loja4}")


media_loja1 = frete_loja1 / quant_frete_loja1
formatted_media = "{:.2f}".format(media_loja1)

print(f"Média de Fretes da loja1: R${formatted_media}")

media_loja2 = frete_loja2 / quant_frete_loja2
formatted_media = "{:.2f}".format(media_loja2)

print(f"Média de Fretes da loja2: R${formatted_media}")

media_loja3 = frete_loja3 / quant_frete_loja3
formatted_media = "{:.2f}".format(media_loja3)

print(f"Média de Fretes da loja3: R${formatted_media}")

media_loja4 = frete_loja4 / quant_frete_loja4
formatted_media = "{:.2f}".format(media_loja4)

print(f"Média de Fretes da loja4: R${formatted_media}")

import matplotlib.pyplot as plt
media = {
    'loja1': media_loja1,
    'loja2': media_loja2,
    'loja3': media_loja3,
    'loja4': media_loja4
}

melhor_loja = max(media, key=media.get)
maior_media = media[melhor_loja]

print(f"A loja com a maior média de Frete é: {melhor_loja} com média de R${maior_media:.2f}")

plt.figure(figsize=(10, 6))
plt.barh(lojas, media_fretes, color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
plt.xlabel("Frete Médio (R$)")
plt.ylabel("Lojas")
plt.title("Frete Médio por Loja")
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Add values to the right of the bars
for i, valor in enumerate(media_fretes):
    plt.text(valor, i, f'{valor:,.2f}', va='center')

plt.show()
# Out:
# Média de Fretes da loja1: R$31.28
# Média de Fretes da loja2: R$33.62
# Média de Fretes da loja3: R$33.07
# Média de Fretes da loja4: R$31.28
# A loja com a maior média de Frete é: loja2 com média de R$33.62

# %% [markdown]
# Relatório

# %% [markdown]
# # Relatorio Final
# #Objetivo
# Este Relatório, tem por objetivo auxiliar o seu João na escolha de qual loja vender para investir em um novo empreendimento.
# Para isto, analisamos cinco fatores, o primeiro é o Faturamento de cada loja:
#
#     ##Faturamento loja1: R$1,384,497.58
#     ##Faturamento loja2: R$1,488,459.06
#     ##Faturamento loja3: R$1,464,025.03
#     ##Faturamento loja4: R$1,384,497.58
#
# Acima, nota-se que a Loja 02 possui o maior faturamento e as Lojas 01 e 04 possui o menor valor de faturamento entre todas as lojas.
#
#
# O segundo fator são as Vendas por Categoria:
#
#
#     ##--- loja1 ---
#     ##Categoria do Produto
#     ##brinquedos               1321
#     ##eletrodomesticos         1258
#     ##eletronicos              1794
#     ##esporte e lazer          1107
#     ##instrumentos musicais     737
#     ##livros                    688
#     ##moveis                   1835
#     ##utilidades domesticas     641
#     ##Name: Avaliação da compra, dtype: int64
#     ##Categoria mais vendida: moveis - Quantidade: 1835
#     ##Categoria menos vendida: utilidades domesticas - Quantidade: 641
#
#
#
#
#     ##--- loja2 ---
#     ##Categoria do Produto
#     ##brinquedos               1260
#     ##eletrodomesticos         1242
#     ##eletronicos              1676
#     ##esporte e lazer          1118
#     ##instrumentos musicais     904
#     ##livros                    778
#     ##moveis                   1809
#     ##utilidades domesticas     737
#     ##Name: Avaliação da compra, dtype: int64
#     ##Categoria mais vendida: moveis - Quantidade: 1809
#     ##Categoria menos vendida: utilidades domesticas - Quantidade: 737
#
#
#
#
#     ##--- loja3 ---
#     ##Categoria do Produto
#     ##brinquedos               1322
#     ####eletrodomesticos         1115
#     ##eletronicos              1798
#     ##esporte e lazer          1091
#     ##instrumentos musicais     709
#     ##livros                    749
#     ##moveis                   2045
#     ##utilidades domesticas     721
#     ##Name: Avaliação da compra, dtype: int64
#     ##Categoria mais vendida: moveis - Quantidade: 2045
#     ##Categoria menos vendida: instrumentos musicais - Quantidade: 709
#
#
#
#
#     ##--- loja4 ---
#     ##Categoria do Produto
#     ##brinquedos               1348
#     ####eletrodomesticos          998
#     ##eletronicos              1807
#     ##esporte e lazer          1123
#     ##instrumentos musicais     665
#     ##livros                    756
#     ##moveis                   1919
#     ##utilidades domesticas     806
#     ##Name: Avaliação da compra, dtype: int64
#     ##Categoria mais vendida: moveis - Quantidade: 1919
#     ##Categoria menos vendida: instrumentos musicais - Quantidade: 665
#
# O fator acima analisado demonstra que entre as quatro lojas, a Loja 1 é foi a que menos vendeu produtos na soma entre categoria mais vendida e categoria menos vendida; e a loja 3 vendeu mais produtos na soma, dentre as outras lojas.
#
#
# O terceiro fator analisado foi a Média de Avaliação das Lojas, um dos fatores mais importantes para determinar a produtividade de um negócio.
#
#
#     ##Média de Avaliações loja1: 3.98
#     ##Média de Avaliações loja2: 4.04
#     ##Média de Avaliações loja3: 4.05
#     ##Média de Avaliações loja4: 4.00
#     ##A loja com mais clientes satisfeitos é: loja3 com média 4.05
#
#
# Como identificado a loja 3 tem a melhor avaliação e a Loja 1, a menor.
#
# Como quarta metrica, temos a identificação dos produtos mais vendidos e os menos vendidos de cada loja.
#
#
#     ##--- loja1 ---
#     ##Produto mais vendido: TV Led UHD 4K (Quantidade: 243)
#     ##Produto menos vendido: Celular ABXY (Quantidade: 126)
#
#
#
#     ##--- loja2 ---
#     ##Produto mais vendido: Iniciando em programação (Quantidade: 260)
#     ##Produto menos vendido: Jogo de tabuleiro (Quantidade: 127)
#
#
#
#     ##--- loja3 ---
#     ##Produto mais vendido: Kit banquetas (Quantidade: 240)
#     ##Produto menos vendido: Micro-ondas (Quantidade: 126)
#
#
#     ##--- loja4 ---
#     ##Produto mais vendido: Cama box (Quantidade: 247)
#     ##Produto menos vendido: Guitarra (Quantidade: 125)
#
#
# A Loja 2 tem o maior número de produtos vendidos, somando 260; enquanto que a Loja 3 é a menor com 240 produtos.
#
#
# Por último, analisamos o frete Médio por Loja:
#
#
#     ##Média de Fretes da loja1: R$31.28
#     ##Média de Fretes da loja2: R$33.62
#     ##Média de Fretes da loja3: R$33.07
#     ##Média de Fretes da loja4: R$31.28
#     ##A loja com a maior média de Frete é: loja2 com média de R$33.62
#
#
# A loja com maior média de custo de frete é a Loja 2; enquanto que a Loja 1 e a Loja 4 tum custo medio menor de frete, dentre todas lojas.
# Portanto, subentende-se que a loja 2 trabalha mais ativamente com fretes.
#
# ##Conclusão
# Extraído todos os dados, verificamos que a Loja 1 e Loja 4 possui menor faturamento e a menor média de fretes por loja; além disso a Loja 1, comparada às Loja 2, Loja 3 e loja 4, detêm a menor média de avaliação e em soma, menor venda por categoria.
#
# Diante disso, sugere-se ao seu João que realize a venda da loja 1, pois, quanto menor a avaliação do público, menos vendas serão realizadas, resultando em baixo faturamento ou saldo negativo em caixa.
#
# Segue abaixo graficos de alguns fatores, para melhor ilustrar o desenvolvimento de cada loja.

# %% [markdown]
# ![grafic_barra.PNG](data:image/png;base64,...)

# %% [markdown]
# ![grafic_linhas.PNG](data:image/png;base64,...)

# %% [markdown]
# ![grafics_coluna.PNG](data:image/png;base64,...)
